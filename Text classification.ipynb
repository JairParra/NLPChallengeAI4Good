# %%
# Task: Text Classification: classify the effect on members in 34 classes (No labels available)
# "Unsupervised classification" using informative text class labels as class prototypes in a vector space
# AI4Good Hackathon
# Alex Merritt
# Requires: https://github.com/facebookresearch/fastText/tree/master/python 
# and https://fasttext.cc/docs/en/crawl-vectors.html

# %%
from fastText import load_model
import csv
import numpy as np

model = load_model('cc.fr.300.bin')

# %%
with open('Indicators.csv') as f:
    indicators = f.readlines()
indicators = [x.strip() for x in indicators] 
  

print(indicators)
# Out:
# ['Autonomie', "Bris de l'isolement", 'Communication', 'Compétences', 'Confiance en soi', 'Connaissance de soi', 'Connaissances', 'Conscientisation / Esprit critique', "Développement (de l'enfant)", 'Développement de pratiques démocratiques', 'Empowerment collectif', 'Empowerment individuel', 'Estime de soi', 'Habiletés cognitives', 'Habiletés dans la vie quotidienne', 'Habiletés sociales', 'Habitudes de vie', 'Identification des besoins', 'Intégration sociale', 'Lien de confiance', 'Liens familiaux', 'Mixité sociale et culturelle', 'Participation citoyenne', 'Plaisir', 'Prise de parole', 'Réciprocité', 'Répit', "Réseau d'entraide", 'Résultats scolaires', 'Sécurité', "Sentiment d'appartenance", 'Sentiment de valorisation', 'Socialisation', 'Soutien']

# %%
def similarity(v1, v2):
    n1 = np.linalg.norm(v1)
    n2 = np.linalg.norm(v2)
    return np.dot(v1, v2) / n1 / n2

# %%
def docIndicatorSimilarity(indicator, row): 
    indicator_words = indicator.split(' ')
    indicator_word_vecs = [model.get_word_vector(word) for word in indicator_words]
    indicator_avg_vec = np.mean(indicator_word_vecs, axis=0)
            
    row_words = row[8].split(' ')
    #print(row[8])
    row_word_vecs = [model.get_word_vector(word) for word in row_words]
    row_avg_vec = np.mean(row_word_vecs, axis=0)
    return similarity(indicator_avg_vec, row_avg_vec)

# %%
d = {}

with open('Baseresultats.csv', newline='') as csvfile:
    reader = csv.reader(csvfile, delimiter=',', quotechar='"')
    next(reader,None)
    for row in reader:
        similarities = [docIndicatorSimilarity(indicator, row) for indicator in indicators]        
        max_similarity = np.argmax(similarities)
        if ('Effet' in row[9]):
            
            d[row[0]] = indicators[max_similarity]
            print("ID: " + row[0] + " " + str(d[row[0]]))
# Out:
# ID: 7848 Développement de pratiques démocratiques
# ID: 193624 Habiletés dans la vie quotidienne
# ID: 163221 Développement de pratiques démocratiques
# ID: 139813 Développement de pratiques démocratiques
# ID: 118-09 Développement de pratiques démocratiques
# ID: 9222 Développement de pratiques démocratiques
# ID: 103 Identification des besoins
# ID: 7895 Développement de pratiques démocratiques
# ID: 7889 Développement de pratiques démocratiques
# ID: 167196 Développement de pratiques démocratiques
# ID: 7907 Développement de pratiques démocratiques
# ID: 6611 Développement de pratiques démocratiques
# ID: 7930 Conscientisation / Esprit critique
# ID: 7810 Développement de pratiques démocratiques
# ID: 8993 Développement de pratiques démocratiques
# ID: 7874 Habiletés dans la vie quotidienne
# ID: 6608 Développement de pratiques démocratiques
# ID: 135613 Développement de pratiques démocratiques
# ID: 9532 Développement de pratiques démocratiques
# ID: 136483 Développement de pratiques démocratiques
# ID: 674 Développement de pratiques démocratiques
# ID: 7133 Développement de pratiques démocratiques
# ID: 175493 Développement de pratiques démocratiques
# ID: 7864 Développement de pratiques démocratiques
# ID: 245189 Développement de pratiques démocratiques
# ID: 7903 Développement de pratiques démocratiques
# ID: 148196 Développement de pratiques démocratiques
# ID: 378495 Développement de pratiques démocratiques
# ID: 7855 Développement de pratiques démocratiques
# ID: 163006 Habiletés dans la vie quotidienne
# ID: 6607 Développement de pratiques démocratiques
# ID: 5142 Développement de pratiques démocratiques
# ID: 140731 Habiletés dans la vie quotidienne
# ID: 182208 Habiletés dans la vie quotidienne
# ID: 7322-06 Conscientisation / Esprit critique
# ID: 267788 Développement de pratiques démocratiques
# ID: 3032 Développement de pratiques démocratiques
# ID: 7871 Conscientisation / Esprit critique
# ID: 118-05 Conscientisation / Esprit critique
# ID: 135618 Développement de pratiques démocratiques
# ID: 7837 Développement de pratiques démocratiques
# ID: 7916 Développement de pratiques démocratiques
# ID: 2588 Développement de pratiques démocratiques
# ID: 7838 Développement de pratiques démocratiques
# ID: 2589 Développement de pratiques démocratiques
# ID: 118-06 Développement de pratiques démocratiques
# ID: 8230 Conscientisation / Esprit critique
# ID: 7885 Développement de pratiques démocratiques
# ID: 1015 Développement de pratiques démocratiques
# ID: 159740 Développement de pratiques démocratiques
# ID: 142125 Développement de pratiques démocratiques
# ID: 164011 Développement de pratiques démocratiques
# ID: 7818 Développement de pratiques démocratiques
# ID: 144698 Développement de pratiques démocratiques
# ID: 310845 Développement de pratiques démocratiques
# ID: 6603 Développement de pratiques démocratiques
# ID: 255384 Développement de pratiques démocratiques
# ID: 7894-01 Habiletés dans la vie quotidienne
# ID: 7831 Développement de pratiques démocratiques
# ID: 135303 Identification des besoins
# ID: 8995 Développement de pratiques démocratiques
# ID: 7934 Développement de pratiques démocratiques
# ID: 1951 Développement de pratiques démocratiques
# ID: 1952 Identification des besoins
# ID: 244982 Développement de pratiques démocratiques
# ID: 135305 Identification des besoins
# ID: 3025 Habiletés dans la vie quotidienne
# ID: 7856 Développement de pratiques démocratiques
# ID: 145120 Développement de pratiques démocratiques
# ID: 6612 Habiletés dans la vie quotidienne
# ID: 138506 Développement de pratiques démocratiques
# ID: 4213 Développement de pratiques démocratiques
# ID: 328045 Développement de pratiques démocratiques
# ID: 1012 Développement de pratiques démocratiques
# ID: 1013 Développement de pratiques démocratiques
# ID: 273241 Développement de pratiques démocratiques
# ID: 7935 Développement de pratiques démocratiques
# ID: 9002 Développement de pratiques démocratiques
# ID: 138531 Développement de pratiques démocratiques
# ID: 118-04 Habiletés dans la vie quotidienne
# ID: 1014 Développement de pratiques démocratiques
# ID: 7880 Conscientisation / Esprit critique
# ID: 225387 Développement de pratiques démocratiques
# ID: 8998 Développement de pratiques démocratiques
# ID: 7875 Habiletés dans la vie quotidienne
# ID: 163225 Développement de pratiques démocratiques
# ID: 167455 Conscientisation / Esprit critique
# ID: 746 Développement de pratiques démocratiques
# ID: 7852 Conscientisation / Esprit critique
# ID: 175256 Lien de confiance
# ID: 118-08 Développement de pratiques démocratiques
# ID: 135611 Habiletés dans la vie quotidienne
# ID: 146173 Développement de pratiques démocratiques
# ID: 3034 Habiletés dans la vie quotidienne
# ID: 7893 Développement de pratiques démocratiques
# ID: 7913 Développement de pratiques démocratiques
# ID: 7860 Habiletés dans la vie quotidienne
# ID: 3024 Développement de pratiques démocratiques
# ID: 7817 Développement de pratiques démocratiques
# ID: 8990 Développement de pratiques démocratiques
# ID: 7468 Développement de pratiques démocratiques
# ID: 7877 Développement de pratiques démocratiques
# ID: 141788 Développement de pratiques démocratiques
# ID: 229866 Développement de pratiques démocratiques
# ID: 140036 Développement de pratiques démocratiques
# ID: 135612 Développement de pratiques démocratiques
# ID: 135609 Développement de pratiques démocratiques
# ID: 3031 Développement de pratiques démocratiques
# ID: 7904 Développement de pratiques démocratiques
# ID: 261489 Habiletés dans la vie quotidienne
# ID: 715-04 Développement de pratiques démocratiques
# ID: 6606 Développement de pratiques démocratiques
# ID: 8231 Conscientisation / Esprit critique
# ID: 4211 Habiletés dans la vie quotidienne
# ID: 6614 Développement de pratiques démocratiques
# ID: 3030 Développement de pratiques démocratiques
# ID: 9422 Développement de pratiques démocratiques
# ID: 4417 Développement de pratiques démocratiques
# ID: 8992 Développement de pratiques démocratiques
# ID: 7499 Développement de pratiques démocratiques
# ID: 7854 Développement de pratiques démocratiques
# ID: 305003 Développement de pratiques démocratiques
# ID: 7908 Conscientisation / Esprit critique
# ID: 8991 Développement de pratiques démocratiques
# ID: 162194 Développement de pratiques démocratiques
# ID: 7825 Conscientisation / Esprit critique
# ID: 193490 Développement de pratiques démocratiques
# ID: 8654 Développement de pratiques démocratiques
# ID: 7878 Développement de pratiques démocratiques
# ID: 3147 Développement de pratiques démocratiques
# ID: 118 Développement de pratiques démocratiques
# ID: 164826 Développement de pratiques démocratiques
# ID: 7826 Développement de pratiques démocratiques
# ID: 135633 Développement de pratiques démocratiques
# ID: 193575 Identification des besoins
# ID: 7853 Développement de pratiques démocratiques
# ID: 7884 Développement de pratiques démocratiques
# ID: 187409 Confiance en soi
# ID: 481 Développement de pratiques démocratiques
# ID: 174157 Conscientisation / Esprit critique
# ID: 118-01 Développement de pratiques démocratiques
# ID: 7823 Développement de pratiques démocratiques
# ID: 7013 Développement de pratiques démocratiques
# ID: 8999 Développement de pratiques démocratiques
# ID: 7891 Identification des besoins
# ID: 5056 Habiletés dans la vie quotidienne
# ID: 7918 Développement de pratiques démocratiques
# ID: 8756 Développement de pratiques démocratiques
# ID: 5579 Développement de pratiques démocratiques
# ID: 5141 Identification des besoins
# ID: 275640 Développement de pratiques démocratiques
# ID: 6609 Développement de pratiques démocratiques
# ID: 354043 Développement de pratiques démocratiques
# ID: 468 Identification des besoins
# ID: 186575 Développement de pratiques démocratiques
# ID: 5143 Développement de pratiques démocratiques
# ID: 210003 Développement de pratiques démocratiques
# ID: 7085 Développement de pratiques démocratiques
# ID: 8779 Développement de pratiques démocratiques
# ID: 7322-09 Développement de pratiques démocratiques
# ID: 1101 Développement de pratiques démocratiques
# ID: 278614 Conscientisation / Esprit critique
# ID: 7897 Développement de pratiques démocratiques
# ID: 7322-08 Conscientisation / Esprit critique
# ID: 7921 Développement de pratiques démocratiques
# ID: 7533 Conscientisation / Esprit critique
# ID: 278611 Conscientisation / Esprit critique
# ID: 7842 Identification des besoins
# ID: 135606 Développement de pratiques démocratiques
# ID: 228373 Développement de pratiques démocratiques
# ID: 7374 Identification des besoins
# ID: 245113 Identification des besoins
# ID: 3026 Développement de pratiques démocratiques
# ID: 262157 Développement de pratiques démocratiques
# ID: 140417 Développement de pratiques démocratiques
# ID: 342354 Développement de pratiques démocratiques
# ID: 145848 Développement de pratiques démocratiques
# ID: 244823 Développement de pratiques démocratiques
# ID: 162178 Développement de pratiques démocratiques
# ID: 3028 Développement de pratiques démocratiques
# ID: 245009 Développement de pratiques démocratiques
# ID: 135636 Développement de pratiques démocratiques
# ID: 227914 Développement de pratiques démocratiques
# ID: 142362 Développement de pratiques démocratiques
# ID: 278352 Développement de pratiques démocratiques
# ID: 9588 Sentiment de valorisation
# ID: 715-03 Développement de pratiques démocratiques
# ID: 162996 Développement de pratiques démocratiques
# ID: 7830 Habitudes de vie
# ID: 141087 Identification des besoins
# ID: 715-02 Développement de pratiques démocratiques
# ID: 9000 Développement de pratiques démocratiques
# ID: 820 Développement de pratiques démocratiques
# ID: 4217 Développement de pratiques démocratiques
# ID: 187913 Développement de pratiques démocratiques
# ID: 423577 Développement de pratiques démocratiques
# ID: 774 Développement de pratiques démocratiques
# ID: 7888 Développement de pratiques démocratiques
# ID: 8229 Conscientisation / Esprit critique
# ID: 245221 Développement de pratiques démocratiques
# ID: 135643 Développement de pratiques démocratiques
# 201
